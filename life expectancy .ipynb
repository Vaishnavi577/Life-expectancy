# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Pls Srinivas\OneDrive\Desktop\shiash\Life_Expectancy.csv")
df.shape
# Out:
# (182, 20)

# %%
df
# Out:
#          Country  Year      Status  Adult_Mortality  Infant_Deaths  Alcohol
# 0    Afghanistan  2015  Developing            263.0             62     0.01  \
# 1        Albania  2015  Developing             74.0              0     4.60
# 2        Algeria  2015  Developing             19.0             21      NaN
# 3         Angola  2015  Developing            335.0             66      NaN
# 4        Antigua  2015  Developing             13.0              0      NaN
# ..           ...   ...         ...              ...            ...      ...
# 177    Venezuela  2015  Developing            157.0              9      NaN
# 178     Viet Nam  2015  Developing            127.0             28      NaN
# 179        Yemen  2015  Developing            224.0             37      NaN
# 180       Zambia  2015  Developing             33.0             27      NaN
# 181     Zimbabwe  2015  Developing            336.0             22      NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            182 non-null    object
#  1   Year               182 non-null    int64
#  2   Status             182 non-null    object
#  3   Adult_Mortality    173 non-null    float64
#  4   Infant_Deaths      182 non-null    int64
#  5   Alcohol            15 non-null     float64
#  6   Hepatitis B        173 non-null    float64
#  7   Measles            182 non-null    int64
#  8   BMI                178 non-null    float64
#  9   Underfive_Deaths   182 non-null    int64
#  10  Polio              182 non-null    int64
#  11  Diphtheria         182 non-null    int64
#  12  HIV                182 non-null    float64
#  13  GDP                157 non-null    float64
#  14  Population         141 non-null    float64
#  15  Malnourished10_19  178 non-null    float64
# ...

# %%
df.describe()
# Out:
#               Year  Adult_Mortality  Infant_Deaths    Alcohol  Hepatitis B
# count   182.000000       173.000000     182.000000  15.000000   173.000000  \
# mean   2014.890110       149.971098      21.741758   2.719333    81.710983
# std       0.457003        95.679846      82.297159   3.887194    25.391991
# min    2013.000000         1.000000       0.000000   0.010000     6.000000
# 25%    2015.000000        74.000000       0.000000   0.010000    78.000000
# 50%    2015.000000       137.000000       2.000000   0.010000    93.000000
# 75%    2015.000000       199.000000      15.000000   5.285000    97.000000
# max    2015.000000       484.000000     910.000000  10.660000    99.000000
#
#            Measles          BMI  Underfive_Deaths        Polio  Diphtheria
# count    182.000000  178.000000         182.000000  182.000000   182.000000  \
# mean    1482.104396   44.411236          28.851648   82.961538    84.357143
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Adult_Mortality', 'Infant_Deaths',
#        'Alcohol', 'Hepatitis B', 'Measles ', 'BMI', 'Underfive_Deaths ',
#        'Polio', 'Diphtheria ', 'HIV', 'GDP', 'Population', 'Malnourished10_19',
#        'Malnourished5_9', 'Income_Index', 'Schooling', 'Life_Expectancy'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                0
# Year                   0
# Status                 0
# Adult_Mortality        9
# Infant_Deaths          0
# Alcohol              167
# Hepatitis B            9
# Measles                0
# BMI                    4
# Underfive_Deaths       0
# Polio                  0
# Diphtheria             0
# HIV                    0
# GDP                   25
# Population            41
# Malnourished10_19      4
# Malnourished5_9        4
# Income_Index          13
# Schooling              9
# Life_Expectancy        9
# dtype: int64

# %%
df.drop(labels=['Alcohol'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Adult_Mortality', 'Infant_Deaths',
#        'Hepatitis B', 'Measles ', 'BMI', 'Underfive_Deaths ', 'Polio',
#        'Diphtheria ', 'HIV', 'GDP', 'Population', 'Malnourished10_19',
#        'Malnourished5_9', 'Income_Index', 'Schooling', 'Life_Expectancy'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country               object
# Year                   int64
# Status                object
# Adult_Mortality      float64
# Infant_Deaths          int64
# Hepatitis B          float64
# Measles                int64
# BMI                  float64
# Underfive_Deaths       int64
# Polio                  int64
# Diphtheria             int64
# HIV                  float64
# GDP                  float64
# Population           float64
# Malnourished10_19    float64
# Malnourished5_9      float64
# Income_Index         float64
# Schooling            float64
# Life_Expectancy      float64
# dtype: object

# %%
df.ffill(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country              0
# Year                 0
# Status               0
# Adult_Mortality      0
# Infant_Deaths        0
# Hepatitis B          0
# Measles              0
# BMI                  0
# Underfive_Deaths     0
# Polio                0
# Diphtheria           0
# HIV                  0
# GDP                  0
# Population           0
# Malnourished10_19    0
# Malnourished5_9      0
# Income_Index         0
# Schooling            0
# Life_Expectancy      0
# dtype: int64

# %%
df.Adult_Mortality=df.Adult_Mortality.astype('int64')
df['Hepatitis B']=df['Hepatitis B'].astype('int64')

# %%
df.dtypes
# Out:
# Country               object
# Year                   int64
# Status                object
# Adult_Mortality        int64
# Infant_Deaths          int64
# Hepatitis B            int64
# Measles                int64
# BMI                  float64
# Underfive_Deaths       int64
# Polio                  int64
# Diphtheria             int64
# HIV                  float64
# GDP                  float64
# Population           float64
# Malnourished10_19    float64
# Malnourished5_9      float64
# Income_Index         float64
# Schooling            float64
# Life_Expectancy      float64
# dtype: object

# %%
a=df_cat.iloc[:,-1:]
a
# Out:
#          Status
# 0    Developing
# 1    Developing
# 2    Developing
# 3    Developing
# 4    Developing
# ..          ...
# 177  Developing
# 178  Developing
# 179  Developing
# 180  Developing
# 181  Developing
#
# [182 rows x 1 columns]

# %%
df1=df.copy()

# %%
dummy=pd.get_dummies(data=a,dtype=int)
dummy
# Out:
#      Status_Developed  Status_Developing
# 0                   0                  1
# 1                   0                  1
# 2                   0                  1
# 3                   0                  1
# 4                   0                  1
# ..                ...                ...
# 177                 0                  1
# 178                 0                  1
# 179                 0                  1
# 180                 0                  1
# 181                 0                  1
#
# [182 rows x 2 columns]

# %%
b=df_cat.iloc[:,:1]
b
# Out:
#          Country
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3         Angola
# 4        Antigua
# ..           ...
# 177    Venezuela
# 178     Viet Nam
# 179        Yemen
# 180       Zambia
# 181     Zimbabwe
#
# [182 rows x 1 columns]

# %%
df_num=df.select_dtypes(include=['int64','float64'])
df_num
# Out:
#      Year  Adult_Mortality  Infant_Deaths  Hepatitis B  Measles    BMI
# 0    2015              263             62           65      1154  19.1  \
# 1    2015               74              0           99         0  58.0
# 2    2015               19             21           95        63  59.5
# 3    2015              335             66           64       118  23.3
# 4    2015               13              0           99         0  47.7
# ..    ...              ...            ...          ...       ...   ...
# 177  2015              157              9           87         0  62.1
# 178  2015              127             28           97       256  17.5
# 179  2015              224             37           69       468  41.3
# 180  2015               33             27            9         9  23.4
# 181  2015              336             22           87         0  31.8
#
#      Underfive_Deaths   Polio  Diphtheria   HIV           GDP  Population
# ...

# %%
for i in df_cat.columns:
    print(df_cat[i].value_counts())
# Out:
# Country
# Afghanistan    1
# New Zealand    1
# Niger          1
# Nigeria        1
# Niue           1
#               ..
# Ghana          1
# Greece         1
# Grenada        1
# Guatemala      1
# Zimbabwe       1
# Name: count, Length: 182, dtype: int64
# Status
# Developing    150
# Developed      32
# Name: count, dtype: int64

# %%
df_cat.dtypes
# Out:
# Country    object
# Status     object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
encoder_cat=pd.DataFrame(le.fit_transform(b),columns=b.columns)
encoder_cat
# Out:
# C:\Users\Pls Srinivas\anaconda3\New folder\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#      Country
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ..       ...
# 177      177
# 178      178
# 179      179
# 180      180
# 181      181
#
# [182 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()
a=mn.fit_transform(df_num)
df_num_mn=pd.DataFrame(a,columns=df_num.columns)
df_num_mn
# Out:
#      Year  Adult_Mortality  Infant_Deaths  Hepatitis B  Measles        BMI
# 0     1.0         0.542443       0.068132     0.634409  0.012767  0.195755  \
# 1     1.0         0.151139       0.000000     1.000000  0.000000  0.654481
# 2     1.0         0.037267       0.023077     0.956989  0.000697  0.672170
# 3     1.0         0.691511       0.072527     0.623656  0.001305  0.245283
# 4     1.0         0.024845       0.000000     1.000000  0.000000  0.533019
# ..    ...              ...            ...          ...       ...       ...
# 177   1.0         0.322981       0.009890     0.870968  0.000000  0.702830
# 178   1.0         0.260870       0.030769     0.978495  0.002832  0.176887
# 179   1.0         0.461698       0.040659     0.677419  0.005178  0.457547
# 180   1.0         0.066253       0.029670     0.032258  0.000100  0.246462
# 181   1.0         0.693582       0.024176     0.870968  0.000000  0.345519
#
# ...

# %%
df2=pd.concat([encoder_cat,dummy,df_num_mn],axis=1)
df2
# Out:
#      Country  Status_Developed  Status_Developing  Year  Adult_Mortality
# 0          0                 0                  1   1.0         0.542443  \
# 1          1                 0                  1   1.0         0.151139
# 2          2                 0                  1   1.0         0.037267
# 3          3                 0                  1   1.0         0.691511
# 4          4                 0                  1   1.0         0.024845
# ..       ...               ...                ...   ...              ...
# 177      177                 0                  1   1.0         0.322981
# 178      178                 0                  1   1.0         0.260870
# 179      179                 0                  1   1.0         0.461698
# 180      180                 0                  1   1.0         0.066253
# 181      181                 0                  1   1.0         0.693582
#
#      Infant_Deaths  Hepatitis B  Measles        BMI  Underfive_Deaths
# ...

# %%
x=df2.iloc[:,:20]
x
# Out:
#      Country  Status_Developed  Status_Developing  Year  Adult_Mortality
# 0          0                 0                  1   1.0         0.542443  \
# 1          1                 0                  1   1.0         0.151139
# 2          2                 0                  1   1.0         0.037267
# 3          3                 0                  1   1.0         0.691511
# 4          4                 0                  1   1.0         0.024845
# ..       ...               ...                ...   ...              ...
# 177      177                 0                  1   1.0         0.322981
# 178      178                 0                  1   1.0         0.260870
# 179      179                 0                  1   1.0         0.461698
# 180      180                 0                  1   1.0         0.066253
# 181      181                 0                  1   1.0         0.693582
#
#      Infant_Deaths  Hepatitis B  Measles        BMI  Underfive_Deaths
# ...

# %%
y=df2.iloc[:,-1:]
y
# Out:
#      Life_Expectancy
# 0           0.378378
# 1           0.724324
# 2           0.664865
# 3           0.037838
# 4           0.686486
# ..               ...
# 177         0.624324
# 178         0.675676
# 179         0.397297
# 180         0.291892
# 181         0.432432
#
# [182 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((127, 20), (55, 20), (127, 1), (55, 1))

# %%
x_train.sort_index(ascending=True, inplace=True)
x_test.sort_index(ascending=True, inplace=True)
y_train.sort_index(ascending=True, inplace=True)
y_test.sort_index(ascending=True, inplace=True)

# %%
import statsmodels.api as sm
MLR_model1 = sm.OLS(y_train, x_train).fit()
MLR_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_Expectancy   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.907e+28
# Date:                Tue, 26 Mar 2024   Prob (F-statistic):               0.00
# Time:                        22:38:52   Log-Likelihood:                 4115.1
# No. Observations:                 127   AIC:                            -8190.
# Df Residuals:                     107   BIC:                            -8133.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[0.68648649],
#        [0.68378378],
#        [0.85945946],
#        [0.82432432],
#        [0.54054054],
#        [0.50810811],
#        [0.7027027 ],
#        [0.63513514],
#        [0.23243243],
#        [0.84324324],
#        [0.91891892],
#        [0.37027027],
#        [0.94594595],
#        [0.33783784],
#        [0.19459459],
#        [0.37297297],
#        [0.51081081],
#        [0.81351351],
#        [0.63243243],
#        [0.81081081],
#        [0.81081081],
#        [0.21621622],
#        [0.85675676],
#        [0.66216216],
#        [0.88378378],
#        [0.33513514],
#        [0.07297297],
#        [0.28108108],
#        [0.39189189],
#        [0.64864865],
#        [0.74324324],
#        [0.19459459],
#        [0.67837838],
#        [0.4       ],
#        [0.4       ],
#        [0.49189189],
#        [0.09459459],
#        [0.72432432],
#        [0.73513514],
#        [0.84594595],
#        [0.40810811],
#        [0.62162162],
#        [0.63513514],
# ...

# %%
y_test
# Out:
#      Life_Expectancy
# 4           0.686486
# 5           0.683784
# 7           0.859459
# 8           0.824324
# 16          0.540541
# 18          0.508108
# 19          0.702703
# 24          0.635135
# 26          0.232432
# 30          0.843243
# 33          0.918919
# 37          0.370270
# 44          0.945946
# 45          0.337838
# 51          0.194595
# 54          0.372973
# 55          0.510811
# 56          0.813514
# 60          0.632432
# 61          0.810811
# 63          0.810811
# 66          0.216216
# 71          0.856757
# 74          0.662162
# 80          0.883784
# 83          0.335135
# 89          0.072973
# 90          0.281081
# 94          0.391892
# 96          0.648649
# 97          0.743243
# 98          0.194595
# 106         0.678378
# 110         0.400000
# 111         0.400000
# 112         0.491892
# 118         0.094595
# 123         0.724324
# 129         0.735135
# 130         0.845946
# 135         0.408108
# 138         0.621622
# ...

# %%
y_pred
# Out:
# array([[0.68648649],
#        [0.68378378],
#        [0.85945946],
#        [0.82432432],
#        [0.54054054],
#        [0.50810811],
#        [0.7027027 ],
#        [0.63513514],
#        [0.23243243],
#        [0.84324324],
#        [0.91891892],
#        [0.37027027],
#        [0.94594595],
#        [0.33783784],
#        [0.19459459],
#        [0.37297297],
#        [0.51081081],
#        [0.81351351],
#        [0.63243243],
#        [0.81081081],
#        [0.81081081],
#        [0.21621622],
#        [0.85675676],
#        [0.66216216],
#        [0.88378378],
#        [0.33513514],
#        [0.07297297],
#        [0.28108108],
#        [0.39189189],
#        [0.64864865],
#        [0.74324324],
#        [0.19459459],
#        [0.67837838],
#        [0.4       ],
#        [0.4       ],
#        [0.49189189],
#        [0.09459459],
#        [0.72432432],
#        [0.73513514],
#        [0.84594595],
#        [0.40810811],
#        [0.62162162],
#        [0.63513514],
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 1.8777789154350536e-27

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 3.7456401616705906e-14

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 4.333334646014607e-14

# %%
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test.Life_Expectancy, y_pred)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.show()

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Country',y='Life_Expectancy',data=df1)
plt.show()

# %%
sns.scatterplot(x='Country',y='Life_Expectancy',data=df1)
plt.show()
